# %%
dbutils.fs.ls("dbfs:/pipelines/0cc9df7a-e8fd-46c4-be2b-0095a9e584c4/checkpoints/")

# %%
# %sql
select * from delta.`dbfs:/pipelines/0cc9df7a-e8fd-46c4-be2b-0095a9e584c4/system/events`

# %%
# %sql
select details:flow_progress.soyrces
from system.events
where event_type = 'flow_progress'

# %%
# %sql
select * from event_log("0cc9df7a-e8fd-46c4-be2b-0095a9e584c4")
